# %% [markdown]
# # End-To-End Example: Today's Weather
#
# This example will input a location and then output today's current weather conditions at that location.
#
# To complete this example we will use the following API's
#
# - Google Geocode api to get GPS coordinates for a location eg. Syracuse, NY
# - Darksky.net forecast api to get the currnt weather conditions for those GPS coordinates

# %%
# Todo list
# input a location eg. Syracuse, ny
# use the google geocode api to get a lat/lng
# use the darksky api and lat/lng to get current weather conditions
# output current weather conditions (temperature and summary (rain, snow, etc...))

# %%
import requests

#first I write these

def google_geocode(location):
    params = {'address' : location}
    url = 'http://maps.googleapis.com/maps/api/geocode/json'
    response = requests.get(url, params = params)
    geodata = response.json()
    return geodata

def darksky_weather(coords):
    key = '7b86dbebab766d0e51ebdb30fd2e4793' # sign up for your own key at https://darksky.net/dev 
    url='https://api.darksky.net/forecast/%s/%f,%f' % (key, coords['lat'], coords['lng'])
    response = requests.get(url)
    weather = response.json()
    return weather


# then test them here
geodata = google_geocode('Syracuse, NY')
coords =geodata['results'][0]['geometry']['location']
weather = darksky_weather(coords)
weather
# Out:
# {'currently': {'apparentTemperature': 38.15,
#   'cloudCover': 0.57,
#   'dewPoint': 31.96,
#   'humidity': 0.78,
#   'icon': 'partly-cloudy-night',
#   'nearestStormBearing': 85,
#   'nearestStormDistance': 61,
#   'ozone': 296.48,
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'pressure': 1025.16,
#   'summary': 'Partly Cloudy',
#   'temperature': 38.15,
#   'time': 1512170571,
#   'uvIndex': 0,
#   'visibility': 10,
#   'windBearing': 148,
#   'windGust': 0,
#   'windSpeed': 0.91},
#  'daily': {'data': [{'apparentTemperatureHigh': 42.85,
#     'apparentTemperatureHighTime': 1512154800,
#     'apparentTemperatureLow': 32.87,
#     'apparentTemperatureLowTime': 1512212400,
#     'apparentTemperatureMax': 42.85,
#     'apparentTemperatureMaxTime': 1512154800,
#     'apparentTemperatureMin': 37.06,
#     'apparentTemperatureMinTime': 1512187200,
#     'cloudCover': 0.59,
#     'dewPoint': 33.89,
#     'humidity': 0.77,
#     'icon': 'partly-cloudy-day',
#     'moonPhase': 0.43,
#     'ozone': 300.64,
#     'precipIntensity': 0.0003,
#     'precipIntensityMax': 0.0018,
#     'precipIntensityMaxTime': 1512144000,
#     'precipProbability': 0.27,
#     'precipType': 'rain',
#     'pressure': 1022.17,
#     'summary': 'Partly cloudy throughout the day.',
#     'sunriseTime': 1512130679,
#     'sunsetTime': 1512163948,
#     'temperatureHigh': 42.85,
#     'temperatureHighTime': 1512154800,
#     'temperatureLow': 36.25,
#     'temperatureLowTime': 1512212400,
#     'temperatureMax': 42.85,
#     'temperatureMaxTime': 1512154800,
#     'temperatureMin': 37.06,
#     'temperatureMinTime': 1512187200,
#     'time': 1512104400,
#     'uvIndex': 1,
#     'uvIndexTime': 1512136800,
#     'visibility': 10,
#     'windBearing': 273,
#     'windGust': 8.24,
#     'windGustTime': 1512129600,
#     'windSpeed': 1.3},
#    {'apparentTemperatureHigh': 46.44,
#     'apparentTemperatureHighTime': 1512244800,
#     'apparentTemperatureLow': 33.06,
#     'apparentTemperatureLowTime': 1512302400,
#     'apparentTemperatureMax': 46.44,
#     'apparentTemperatureMaxTime': 1512244800,
#     'apparentTemperatureMin': 32.87,
#     'apparentTemperatureMinTime': 1512212400,
#     'cloudCover': 0.82,
#     'dewPoint': 31.14,
#     'humidity': 0.69,
#     'icon': 'partly-cloudy-day',
#     'moonPhase': 0.46,
#     'ozone': 297.61,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0003,
#     'precipIntensityMaxTime': 1512259200,
#     'precipProbability': 0.09,
#     'precipType': 'rain',
#     'pressure': 1024.1,
#     'summary': 'Mostly cloudy throughout the day.',
#     'sunriseTime': 1512217144,
#     'sunsetTime': 1512250330,
#     'temperatureHigh': 46.68,
#     'temperatureHighTime': 1512241200,
#     'temperatureLow': 36.16,
#     'temperatureLowTime': 1512302400,
#     'temperatureMax': 46.68,
#     'temperatureMaxTime': 1512241200,
#     'temperatureMin': 36.25,
#     'temperatureMinTime': 1512212400,
#     'time': 1512190800,
#     'uvIndex': 1,
#     'uvIndexTime': 1512226800,
#     'visibility': 10,
#     'windBearing': 176,
#     'windGust': 7.04,
#     'windGustTime': 1512234000,
#     'windSpeed': 3.71},
#    {'apparentTemperatureHigh': 49.52,
#     'apparentTemperatureHighTime': 1512331200,
#     'apparentTemperatureLow': 33.49,
#     'apparentTemperatureLowTime': 1512388800,
#     'apparentTemperatureMax': 49.52,
#     'apparentTemperatureMaxTime': 1512331200,
#     'apparentTemperatureMin': 33.06,
#     'apparentTemperatureMinTime': 1512302400,
#     'cloudCover': 0.47,
#     'dewPoint': 33.25,
#     'humidity': 0.72,
#     'icon': 'fog',
#     'moonPhase': 0.51,
#     'ozone': 317.59,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0002,
#     'precipIntensityMaxTime': 1512356400,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'pressure': 1023.52,
#     'summary': 'Foggy in the morning.',
#     'sunriseTime': 1512303606,
#     'sunsetTime': 1512336714,
#     'temperatureHigh': 49.61,
#     'temperatureHighTime': 1512327600,
#     'temperatureLow': 37.43,
#     'temperatureLowTime': 1512388800,
#     'temperatureMax': 49.61,
#     'temperatureMaxTime': 1512327600,
#     'temperatureMin': 36.16,
#     'temperatureMinTime': 1512302400,
#     'time': 1512277200,
#     'uvIndex': 1,
#     'uvIndexTime': 1512313200,
#     'visibility': 9.09,
#     'windBearing': 186,
#     'windGust': 7.18,
#     'windGustTime': 1512280800,
#     'windSpeed': 2.18},
#    {'apparentTemperatureHigh': 50.08,
#     'apparentTemperatureHighTime': 1512414000,
#     'apparentTemperatureLow': 38.67,
#     'apparentTemperatureLowTime': 1512442800,
#     'apparentTemperatureMax': 50.08,
#     'apparentTemperatureMaxTime': 1512414000,
#     'apparentTemperatureMin': 33.49,
#     'apparentTemperatureMinTime': 1512388800,
#     'cloudCover': 0.55,
#     'dewPoint': 32.58,
#     'humidity': 0.65,
#     'icon': 'wind',
#     'moonPhase': 0.54,
#     'ozone': 307.67,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0002,
#     'precipIntensityMaxTime': 1512396000,
#     'precipProbability': 0.09,
#     'precipType': 'rain',
#     'pressure': 1025.95,
#     'summary': 'Mostly cloudy throughout the day and windy overnight.',
#     'sunriseTime': 1512390068,
#     'sunsetTime': 1512423100,
#     'temperatureHigh': 50.08,
#     'temperatureHighTime': 1512414000,
#     'temperatureLow': 45.19,
#     'temperatureLowTime': 1512442800,
#     'temperatureMax': 50.08,
#     'temperatureMaxTime': 1512414000,
#     'temperatureMin': 37.43,
#     'temperatureMinTime': 1512388800,
#     'time': 1512363600,
#     'uvIndex': 1,
#     'uvIndexTime': 1512396000,
#     'visibility': 10,
#     'windBearing': 162,
#     'windGust': 40.79,
#     'windGustTime': 1512446400,
#     'windSpeed': 7.77},
#    {'apparentTemperatureHigh': 54.97,
#     'apparentTemperatureHighTime': 1512507600,
#     'apparentTemperatureLow': 27.96,
#     'apparentTemperatureLowTime': 1512565200,
#     'apparentTemperatureMax': 54.97,
#     'apparentTemperatureMaxTime': 1512507600,
#     'apparentTemperatureMin': 39.97,
#     'apparentTemperatureMinTime': 1512453600,
#     'cloudCover': 0.99,
#     'dewPoint': 42.53,
#     'humidity': 0.71,
#     'icon': 'rain',
#     'moonPhase': 0.58,
#     'ozone': 291.93,
#     'precipIntensity': 0.0179,
#     'precipIntensityMax': 0.0558,
#     'precipIntensityMaxTime': 1512529200,
#     'precipProbability': 0.76,
#     'precipType': 'rain',
#     'pressure': 1014.25,
#     'summary': 'Windy until afternoon and rain starting in the afternoon.',
#     'sunriseTime': 1512476528,
#     'sunsetTime': 1512509489,
#     'temperatureHigh': 54.97,
#     'temperatureHighTime': 1512507600,
#     'temperatureLow': 35,
#     'temperatureLowTime': 1512565200,
#     'temperatureMax': 54.97,
#     'temperatureMaxTime': 1512507600,
#     'temperatureMin': 46.73,
#     'temperatureMinTime': 1512453600,
#     'time': 1512450000,
#     'uvIndex': 1,
#     'uvIndexTime': 1512486000,
#     'windBearing': 186,
#     'windGust': 48.44,
#     'windGustTime': 1512475200,
#     'windSpeed': 13.92},
#    {'apparentTemperatureHigh': 31.34,
#     'apparentTemperatureHighTime': 1512579600,
#     'apparentTemperatureLow': 20.97,
#     'apparentTemperatureLowTime': 1512640800,
#     'apparentTemperatureMax': 51.36,
#     'apparentTemperatureMaxTime': 1512536400,
#     'apparentTemperatureMin': 21.31,
#     'apparentTemperatureMinTime': 1512619200,
#     'cloudCover': 0.77,
#     'dewPoint': 22.24,
#     'humidity': 0.56,
#     'icon': 'partly-cloudy-day',
#     'moonPhase': 0.61,
#     'ozone': 310.46,
#     'precipAccumulation': 0.107,
#     'precipIntensity': 0.0103,
#     'precipIntensityMax': 0.0449,
#     'precipIntensityMaxTime': 1512536400,
#     'precipProbability': 0.73,
#     'precipType': 'snow',
#     'pressure': 1015.17,
#     'summary': 'Mostly cloudy until evening.',
#     'sunriseTime': 1512562987,
#     'sunsetTime': 1512595880,
#     'temperatureHigh': 37.43,
#     'temperatureHighTime': 1512583200,
#     'temperatureLow': 27,
#     'temperatureLowTime': 1512644400,
#     'temperatureMax': 51.36,
#     'temperatureMaxTime': 1512536400,
#     'temperatureMin': 28.64,
#     'temperatureMinTime': 1512619200,
#     'time': 1512536400,
#     'uvIndex': 1,
#     'uvIndexTime': 1512572400,
#     'windBearing': 274,
#     'windGust': 26.24,
#     'windGustTime': 1512536400,
#     'windSpeed': 7.78},
#    {'apparentTemperatureHigh': 33.97,
#     'apparentTemperatureHighTime': 1512676800,
#     'apparentTemperatureLow': 21.2,
#     'apparentTemperatureLowTime': 1512734400,
#     'apparentTemperatureMax': 33.97,
#     'apparentTemperatureMaxTime': 1512676800,
#     'apparentTemperatureMin': 20.97,
#     'apparentTemperatureMinTime': 1512640800,
#     'cloudCover': 0.29,
#     'dewPoint': 17.57,
#     'humidity': 0.58,
#     'icon': 'partly-cloudy-night',
#     'moonPhase': 0.65,
#     'ozone': 324.7,
#     'precipAccumulation': 0.032,
#     'precipIntensity': 0.0002,
#     'precipIntensityMax': 0.0007,
#     'precipIntensityMaxTime': 1512691200,
#     'precipProbability': 0.08,
#     'precipType': 'snow',
#     'pressure': 1016.26,
#     'summary': 'Mostly cloudy starting in the afternoon.',
#     'sunriseTime': 1512649444,
#     'sunsetTime': 1512682273,
#     'temperatureHigh': 37.76,
#     'temperatureHighTime': 1512673200,
#     'temperatureLow': 26.12,
#     'temperatureLowTime': 1512734400,
#     'temperatureMax': 37.76,
#     'temperatureMaxTime': 1512673200,
#     'temperatureMin': 27,
#     'temperatureMinTime': 1512644400,
#     'time': 1512622800,
#     'uvIndex': 1,
#     'uvIndexTime': 1512655200,
#     'windBearing': 232,
#     'windGust': 20.64,
#     'windGustTime': 1512622800,
#     'windSpeed': 4.02},
#    {'apparentTemperatureHigh': 31.79,
#     'apparentTemperatureHighTime': 1512756000,
#     'apparentTemperatureLow': 16.53,
#     'apparentTemperatureLowTime': 1512824400,
#     'apparentTemperatureMax': 31.79,
#     'apparentTemperatureMaxTime': 1512756000,
#     'apparentTemperatureMin': 21.2,
#     'apparentTemperatureMinTime': 1512734400,
#     'cloudCover': 0.86,
#     'dewPoint': 16.97,
#     'humidity': 0.57,
#     'icon': 'partly-cloudy-day',
#     'moonPhase': 0.69,
#     'ozone': 343.1,
#     'precipAccumulation': 0.177,
#     'precipIntensity': 0.0009,
#     'precipIntensityMax': 0.0032,
#     'precipIntensityMaxTime': 1512756000,
#     'precipProbability': 0.09,
#     'precipType': 'snow',
#     'pressure': 1016.77,
#     'summary': 'Mostly cloudy throughout the day.',
#     'sunriseTime': 1512735899,
#     'sunsetTime': 1512768669,
#     'temperatureHigh': 37.73,
#     'temperatureHighTime': 1512756000,
#     'temperatureLow': 25.09,
#     'temperatureLowTime': 1512824400,
#     'temperatureMax': 37.73,
#     'temperatureMaxTime': 1512756000,
#     'temperatureMin': 26.12,
#     'temperatureMinTime': 1512734400,
#     'time': 1512709200,
#     'uvIndex': 1,
#     'uvIndexTime': 1512745200,
#     'windBearing': 173,
#     'windGust': 29.14,
#     'windGustTime': 1512792000,
#     'windSpeed': 3.65}],
#   'icon': 'rain',
#   'summary': 'Mixed precipitation on Tuesday and Wednesday, with temperatures peaking at 55°F on Tuesday.'},
#  'flags': {'isd-stations': ['718200-99999',
#    '725146-54773',
#    '725146-99999',
#    '725155-94761',
#    '725155-99999',
#    '725190-14771',
#    '725194-54778',
#    '725194-99999',
#    '725195-99999',
#    '725196-14717',
#    '725196-64775',
#    '725197-94794',
#    '997264-99999',
#    '999999-14771',
#    '999999-64758',
#    '999999-94781'],
#   'sources': ['isd',
#    'nearest-precip',
#    'nwspa',
#    'cmc',
#    'gfs',
#    'hrrr',
#    'madis',
#    'nam',
#    'sref',
#    'darksky'],
#   'units': 'us'},
#  'hourly': {'data': [{'apparentTemperature': 38.24,
#     'cloudCover': 0.63,
#     'dewPoint': 32.31,
#     'humidity': 0.79,
#     'icon': 'partly-cloudy-night',
#     'ozone': 296.88,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1024.95,
#     'summary': 'Mostly Cloudy',
#     'temperature': 38.24,
#     'time': 1512169200,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 151,
#     'windGust': 0,
#     'windSpeed': 1.26},
#    {'apparentTemperature': 38.02,
#     'cloudCover': 0.48,
#     'dewPoint': 31.37,
#     'humidity': 0.77,
#     'icon': 'partly-cloudy-night',
#     'ozone': 295.83,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1025.5,
#     'summary': 'Partly Cloudy',
#     'temperature': 38.02,
#     'time': 1512172800,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 129,
#     'windGust': 0,
#     'windSpeed': 0.35},
#    {'apparentTemperature': 38.23,
#     'cloudCover': 0.5,
#     'dewPoint': 30.32,
#     'humidity': 0.73,
#     'icon': 'partly-cloudy-night',
#     'ozone': 295.63,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1025.85,
#     'summary': 'Partly Cloudy',
#     'temperature': 38.23,
#     'time': 1512176400,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 24,
#     'windGust': 1.86,
#     'windSpeed': 1.53},
#    {'apparentTemperature': 37.98,
#     'cloudCover': 0.66,
#     'dewPoint': 29.63,
#     'humidity': 0.72,
#     'icon': 'partly-cloudy-night',
#     'ozone': 295.79,
#     'precipAccumulation': 0,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.01,
#     'precipType': 'snow',
#     'pressure': 1025.96,
#     'summary': 'Mostly Cloudy',
#     'temperature': 37.98,
#     'time': 1512180000,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 99,
#     'windGust': 3.03,
#     'windSpeed': 2.17},
#    {'apparentTemperature': 37.37,
#     'cloudCover': 0.78,
#     'dewPoint': 29.3,
#     'humidity': 0.72,
#     'icon': 'partly-cloudy-night',
#     'ozone': 295.97,
#     'precipAccumulation': 0,
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.02,
#     'precipType': 'snow',
#     'pressure': 1025.93,
#     'summary': 'Mostly Cloudy',
#     'temperature': 37.37,
#     'time': 1512183600,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 162,
#     'windGust': 3.1,
#     'windSpeed': 2.58},
#    {'apparentTemperature': 37.06,
#     'cloudCover': 0.73,
#     'dewPoint': 29.09,
#     'humidity': 0.73,
#     'icon': 'partly-cloudy-night',
#     'ozone': 295.77,
#     'precipAccumulation': 0,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.01,
#     'precipType': 'snow',
#     'pressure': 1025.69,
#     'summary': 'Mostly Cloudy',
#     'temperature': 37.06,
#     'time': 1512187200,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 182,
#     'windGust': 3.27,
#     'windSpeed': 2.98},
#    {'apparentTemperature': 34.56,
#     'cloudCover': 0.6,
#     'dewPoint': 28.94,
#     'humidity': 0.72,
#     'icon': 'partly-cloudy-night',
#     'ozone': 295.49,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1025.34,
#     'summary': 'Mostly Cloudy',
#     'temperature': 37.09,
#     'time': 1512190800,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 181,
#     'windGust': 3.59,
#     'windSpeed': 3.43},
#    {'apparentTemperature': 34.44,
#     'cloudCover': 0.55,
#     'dewPoint': 28.87,
#     'humidity': 0.71,
#     'icon': 'partly-cloudy-night',
#     'ozone': 294.96,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1025.15,
#     'summary': 'Partly Cloudy',
#     'temperature': 37.28,
#     'time': 1512194400,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 178,
#     'windGust': 3.94,
#     'windSpeed': 3.75},
#    {'apparentTemperature': 34.4,
#     'cloudCover': 0.67,
#     'dewPoint': 29.01,
#     'humidity': 0.72,
#     'icon': 'partly-cloudy-night',
#     'ozone': 294.23,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1025.33,
#     'summary': 'Mostly Cloudy',
#     'temperature': 37.32,
#     'time': 1512198000,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 178,
#     'windGust': 4.22,
#     'windSpeed': 3.83},
#    {'apparentTemperature': 34.32,
#     'cloudCover': 0.86,
#     'dewPoint': 29.21,
#     'humidity': 0.72,
#     'icon': 'partly-cloudy-night',
#     'ozone': 293.29,
#     'precipAccumulation': 0,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.01,
#     'precipType': 'snow',
#     'pressure': 1025.67,
#     'summary': 'Mostly Cloudy',
#     'temperature': 37.22,
#     'time': 1512201600,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 175,
#     'windGust': 4.49,
#     'windSpeed': 3.79},
#    {'apparentTemperature': 34.02,
#     'cloudCover': 0.99,
#     'dewPoint': 29.33,
#     'humidity': 0.74,
#     'icon': 'cloudy',
#     'ozone': 292.57,
#     'precipAccumulation': 0,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.01,
#     'precipType': 'snow',
#     'pressure': 1025.84,
#     'summary': 'Overcast',
#     'temperature': 36.97,
#     'time': 1512205200,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 171,
#     'windGust': 4.78,
#     'windSpeed': 3.8},
#    {'apparentTemperature': 33.37,
#     'cloudCover': 0.97,
#     'dewPoint': 29.23,
#     'humidity': 0.75,
#     'icon': 'cloudy',
#     'ozone': 292,
#     'precipAccumulation': 0,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.01,
#     'precipType': 'snow',
#     'pressure': 1025.75,
#     'summary': 'Overcast',
#     'temperature': 36.53,
#     'time': 1512208800,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 166,
#     'windGust': 4.99,
#     'windSpeed': 3.95},
#    {'apparentTemperature': 32.87,
#     'cloudCover': 0.93,
#     'dewPoint': 29.04,
#     'humidity': 0.75,
#     'icon': 'partly-cloudy-night',
#     'ozone': 291.62,
#     'precipAccumulation': 0,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.01,
#     'precipType': 'snow',
#     'pressure': 1025.5,
#     'summary': 'Mostly Cloudy',
#     'temperature': 36.25,
#     'time': 1512212400,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 161,
#     'windGust': 5.16,
#     'windSpeed': 4.12},
#    {'apparentTemperature': 32.93,
#     'cloudCover': 0.9,
#     'dewPoint': 29.14,
#     'humidity': 0.75,
#     'icon': 'partly-cloudy-night',
#     'ozone': 291.4,
#     'precipAccumulation': 0,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.01,
#     'precipType': 'snow',
#     'pressure': 1025.27,
#     'summary': 'Mostly Cloudy',
#     'temperature': 36.39,
#     'time': 1512216000,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 160,
#     'windGust': 5.39,
#     'windSpeed': 4.22},
#    {'apparentTemperature': 34.03,
#     'cloudCover': 0.87,
#     'dewPoint': 29.72,
#     'humidity': 0.74,
#     'icon': 'partly-cloudy-day',
#     'ozone': 291.47,
#     'precipAccumulation': 0,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.01,
#     'precipType': 'snow',
#     'pressure': 1025.22,
#     'summary': 'Mostly Cloudy',
#     'temperature': 37.37,
#     'time': 1512219600,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 161,
#     'windGust': 5.71,
#     'windSpeed': 4.26},
#    {'apparentTemperature': 36.51,
#     'cloudCover': 0.85,
#     'dewPoint': 30.54,
#     'humidity': 0.7,
#     'icon': 'partly-cloudy-day',
#     'ozone': 291.76,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'pressure': 1025.18,
#     'summary': 'Mostly Cloudy',
#     'temperature': 39.5,
#     'time': 1512223200,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 165,
#     'windGust': 6.11,
#     'windSpeed': 4.25},
#    {'apparentTemperature': 39.13,
#     'cloudCover': 0.85,
#     'dewPoint': 31.23,
#     'humidity': 0.66,
#     'icon': 'partly-cloudy-day',
#     'ozone': 292.24,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'pressure': 1024.99,
#     'summary': 'Mostly Cloudy',
#     'temperature': 41.74,
#     'time': 1512226800,
#     'uvIndex': 1,
#     'visibility': 10,
#     'windBearing': 171,
#     'windGust': 6.45,
#     'windSpeed': 4.22},
#    {'apparentTemperature': 41.5,
#     'cloudCover': 0.89,
#     'dewPoint': 31.57,
#     'humidity': 0.62,
#     'icon': 'partly-cloudy-day',
#     'ozone': 292.78,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'pressure': 1024.42,
#     'summary': 'Mostly Cloudy',
#     'temperature': 43.78,
#     'time': 1512230400,
#     'uvIndex': 1,
#     'visibility': 10,
#     'windBearing': 183,
#     'windGust': 6.77,
#     'windSpeed': 4.22},
#    {'apparentTemperature': 43.44,
#     'cloudCover': 0.95,
#     'dewPoint': 31.77,
#     'humidity': 0.59,
#     'icon': 'cloudy',
#     'ozone': 293.47,
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'pressure': 1023.69,
#     'summary': 'Overcast',
#     'temperature': 45.45,
#     'time': 1512234000,
#     'uvIndex': 1,
#     'visibility': 10,
#     'windBearing': 197,
#     'windGust': 7.04,
#     'windSpeed': 4.22},
#    {'apparentTemperature': 44.74,
#     'cloudCover': 0.99,
#     'dewPoint': 32.02,
#     'humidity': 0.57,
#     'icon': 'cloudy',
#     'ozone': 294.72,
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'pressure': 1023.12,
#     'summary': 'Overcast',
#     'temperature': 46.44,
#     'time': 1512237600,
#     'uvIndex': 1,
#     'visibility': 10,
#     'windBearing': 206,
#     'windGust': 6.98,
#     'windSpeed': 4.03},
#    {'apparentTemperature': 45.49,
#     'cloudCover': 1,
#     'dewPoint': 32.56,
#     'humidity': 0.58,
#     'icon': 'cloudy',
#     'ozone': 297.03,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'pressure': 1022.83,
#     'summary': 'Overcast',
#     'temperature': 46.68,
#     'time': 1512241200,
#     'uvIndex': 1,
#     'visibility': 10,
#     'windBearing': 205,
#     'windGust': 6.19,
#     'windSpeed': 3.46},
#    {'apparentTemperature': 46.44,
#     'cloudCover': 1,
#     'dewPoint': 33.18,
#     'humidity': 0.6,
#     'icon': 'cloudy',
#     'ozone': 299.86,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'pressure': 1022.68,
#     'summary': 'Overcast',
#     'temperature': 46.44,
#     'time': 1512244800,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 197,
#     'windGust': 5.04,
#     'windSpeed': 2.73},
#    {'apparentTemperature': 45.48,
#     'cloudCover': 1,
#     'dewPoint': 33.52,
#     'humidity': 0.63,
#     'icon': 'cloudy',
#     'ozone': 302.47,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'pressure': 1022.61,
#     'summary': 'Overcast',
#     'temperature': 45.48,
#     'time': 1512248400,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 188,
#     'windGust': 4.15,
#     'windSpeed': 2.34},
#    {'apparentTemperature': 44.36,
#     'cloudCover': 0.95,
#     'dewPoint': 33.5,
#     'humidity': 0.65,
#     'icon': 'cloudy',
#     'ozone': 304.66,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'pressure': 1022.56,
#     'summary': 'Overcast',
#     'temperature': 44.36,
#     'time': 1512252000,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 177,
#     'windGust': 3.78,
#     'windSpeed': 2.55},
#    {'apparentTemperature': 41.9,
#     'cloudCover': 0.89,
#     'dewPoint': 33.24,
#     'humidity': 0.68,
#     'icon': 'partly-cloudy-night',
#     'ozone': 306.66,
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'pressure': 1022.59,
#     'summary': 'Mostly Cloudy',
#     'temperature': 43.18,
#     'time': 1512255600,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 166,
#     'windGust': 3.7,
#     'windSpeed': 3.06},
#    {'apparentTemperature': 40.18,
#     'cloudCover': 0.8,
#     'dewPoint': 32.93,
#     'humidity': 0.7,
#     'icon': 'partly-cloudy-night',
#     'ozone': 307.63,
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'pressure': 1022.68,
#     'summary': 'Mostly Cloudy',
#     'temperature': 42.13,
#     'time': 1512259200,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 160,
#     'windGust': 3.89,
#     'windSpeed': 3.58},
#    {'apparentTemperature': 38.78,
#     'cloudCover': 0.68,
#     'dewPoint': 32.64,
#     'humidity': 0.71,
#     'icon': 'partly-cloudy-night',
#     'ozone': 306.98,
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'pressure': 1022.85,
#     'summary': 'Mostly Cloudy',
#     'temperature': 41.23,
#     'time': 1512262800,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 163,
#     'windGust': 4.25,
#     'windSpeed': 3.96},
#    {'apparentTemperature': 37.5,
#     'cloudCover': 0.55,
#     'dewPoint': 32.29,
#     'humidity': 0.73,
#     'icon': 'partly-cloudy-night',
#     'ozone': 305.49,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'pressure': 1023.04,
#     'summary': 'Partly Cloudy',
#     'temperature': 40.41,
#     'time': 1512266400,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 172,
#     'windGust': 4.72,
#     'windSpeed': 4.32},
#    {'apparentTemperature': 36.5,
#     'cloudCover': 0.47,
#     'dewPoint': 32.03,
#     'humidity': 0.74,
#     'icon': 'partly-cloudy-night',
#     'ozone': 304.56,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1023.11,
#     'summary': 'Partly Cloudy',
#     'temperature': 39.76,
#     'time': 1512270000,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 177,
#     'windGust': 5.32,
#     'windSpeed': 4.61},
#    {'apparentTemperature': 36.03,
#     'cloudCover': 0.45,
#     'dewPoint': 31.87,
#     'humidity': 0.74,
#     'icon': 'partly-cloudy-night',
#     'ozone': 305.2,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1022.9,
#     'summary': 'Partly Cloudy',
#     'temperature': 39.47,
#     'time': 1512273600,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 179,
#     'windGust': 6.04,
#     'windSpeed': 4.77},
#    {'apparentTemperature': 35.94,
#     'cloudCover': 0.46,
#     'dewPoint': 31.74,
#     'humidity': 0.74,
#     'icon': 'partly-cloudy-night',
#     'ozone': 306.57,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1022.53,
#     'summary': 'Partly Cloudy',
#     'temperature': 39.43,
#     'time': 1512277200,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 178,
#     'windGust': 6.76,
#     'windSpeed': 4.82},
#    {'apparentTemperature': 35.9,
#     'cloudCover': 0.49,
#     'dewPoint': 31.61,
#     'humidity': 0.74,
#     'icon': 'partly-cloudy-night',
#     'ozone': 308,
#     'precipAccumulation': 0,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.02,
#     'precipType': 'snow',
#     'pressure': 1022.24,
#     'summary': 'Partly Cloudy',
#     'temperature': 39.35,
#     'time': 1512280800,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 178,
#     'windGust': 7.18,
#     'windSpeed': 4.76},
#    {'apparentTemperature': 35.66,
#     'cloudCover': 0.55,
#     'dewPoint': 31.62,
#     'humidity': 0.75,
#     'icon': 'partly-cloudy-night',
#     'ozone': 309.22,
#     'precipAccumulation': 0,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.02,
#     'precipType': 'snow',
#     'pressure': 1022.1,
#     'summary': 'Partly Cloudy',
#     'temperature': 38.99,
#     'time': 1512284400,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 179,
#     'windGust': 7.11,
#     'windSpeed': 4.55},
#    {'apparentTemperature': 35.26,
#     'cloudCover': 0.62,
#     'dewPoint': 31.69,
#     'humidity': 0.77,
#     'icon': 'partly-cloudy-night',
#     'ozone': 310.54,
#     'precipAccumulation': 0,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.02,
#     'precipType': 'snow',
#     'pressure': 1022.05,
#     'summary': 'Mostly Cloudy',
#     'temperature': 38.39,
#     'time': 1512288000,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 180,
#     'windGust': 6.75,
#     'windSpeed': 4.2},
#    {'apparentTemperature': 34.77,
#     'cloudCover': 0.7,
#     'dewPoint': 31.56,
#     'humidity': 0.78,
#     'icon': 'partly-cloudy-night',
#     'ozone': 312.36,
#     'precipAccumulation': 0,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.01,
#     'precipType': 'snow',
#     'pressure': 1022.14,
#     'summary': 'Mostly Cloudy',
#     'temperature': 37.75,
#     'time': 1512291600,
#     'uvIndex': 0,
#     'visibility': 7.74,
#     'windBearing': 180,
#     'windGust': 6.3,
#     'windSpeed': 3.95},
#    {'apparentTemperature': 33.96,
#     'cloudCover': 0.8,
#     'dewPoint': 30.98,
#     'humidity': 0.79,
#     'icon': 'partly-cloudy-night',
#     'ozone': 315.11,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1022.4,
#     'summary': 'Mostly Cloudy',
#     'temperature': 36.97,
#     'time': 1512295200,
#     'uvIndex': 0,
#     'visibility': 4.79,
#     'windBearing': 180,
#     'windGust': 5.77,
#     'windSpeed': 3.86},
#    {'apparentTemperature': 33.29,
#     'cloudCover': 0.9,
#     'dewPoint': 30.2,
#     'humidity': 0.78,
#     'icon': 'fog',
#     'ozone': 318.28,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1022.8,
#     'summary': 'Foggy',
#     'temperature': 36.37,
#     'time': 1512298800,
#     'uvIndex': 0,
#     'visibility': 1.77,
#     'windBearing': 180,
#     'windGust': 5.18,
#     'windSpeed': 3.85},
#    {'apparentTemperature': 33.06,
#     'cloudCover': 0.96,
#     'dewPoint': 29.97,
#     'humidity': 0.78,
#     'icon': 'fog',
#     'ozone': 321.12,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1023.11,
#     'summary': 'Foggy',
#     'temperature': 36.16,
#     'time': 1512302400,
#     'uvIndex': 0,
#     'visibility': 0.01,
#     'windBearing': 181,
#     'windGust': 4.88,
#     'windSpeed': 3.83},
#    {'apparentTemperature': 33.9,
#     'cloudCover': 0.87,
#     'dewPoint': 30.66,
#     'humidity': 0.78,
#     'icon': 'fog',
#     'ozone': 323.35,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1023.29,
#     'summary': 'Foggy',
#     'temperature': 36.9,
#     'time': 1512306000,
#     'uvIndex': 0,
#     'visibility': 0.83,
#     'windBearing': 184,
#     'windGust': 5.16,
#     'windSpeed': 3.84},
#    {'apparentTemperature': 35.99,
#     'cloudCover': 0.75,
#     'dewPoint': 31.83,
#     'humidity': 0.76,
#     'icon': 'partly-cloudy-day',
#     'ozone': 325.07,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1023.38,
#     'summary': 'Mostly Cloudy',
#     'temperature': 38.73,
#     'time': 1512309600,
#     'uvIndex': 0,
#     'visibility': 2.32,
#     'windBearing': 188,
#     'windGust': 5.74,
#     'windSpeed': 3.86},
#    {'apparentTemperature': 38.89,
#     'cloudCover': 0.66,
#     'dewPoint': 32.87,
#     'humidity': 0.72,
#     'icon': 'partly-cloudy-day',
#     'ozone': 326.46,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'pressure': 1023.35,
#     'summary': 'Mostly Cloudy',
#     'temperature': 41.21,
#     'time': 1512313200,
#     'uvIndex': 1,
#     'visibility': 3.77,
#     'windBearing': 196,
#     'windGust': 6.11,
#     'windSpeed': 3.81},
#    {'apparentTemperature': 41.81,
#     'cloudCover': 0.5,
#     'dewPoint': 33.52,
#     'humidity': 0.67,
#     'icon': 'partly-cloudy-day',
#     'ozone': 327.43,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'pressure': 1023.24,
#     'summary': 'Partly Cloudy',
#     'temperature': 43.68,
#     'time': 1512316800,
#     'uvIndex': 1,
#     'visibility': 7.41,
#     'windBearing': 220,
#     'windGust': 6.11,
#     'windSpeed': 3.72},
#    {'apparentTemperature': 45.23,
#     'cloudCover': 0.33,
#     'dewPoint': 34.02,
#     'humidity': 0.61,
#     'icon': 'partly-cloudy-day',
#     'ozone': 328,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'pressure': 1022.95,
#     'summary': 'Partly Cloudy',
#     'temperature': 46.54,
#     'time': 1512320400,
#     'uvIndex': 1,
#     'visibility': 10,
#     'windBearing': 250,
#     'windGust': 5.93,
#     'windSpeed': 3.57},
#    {'apparentTemperature': 47.59,
#     'cloudCover': 0.37,
#     'dewPoint': 34.43,
#     'humidity': 0.58,
#     'icon': 'partly-cloudy-day',
#     'ozone': 327.42,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'pressure': 1022.63,
#     'summary': 'Partly Cloudy',
#     'temperature': 48.48,
#     'time': 1512324000,
#     'uvIndex': 1,
#     'visibility': 10,
#     'windBearing': 242,
#     'windGust': 5.53,
#     'windSpeed': 3.4},
#    {'apparentTemperature': 49.12,
#     'cloudCover': 0.13,
#     'dewPoint': 34.89,
#     'humidity': 0.57,
#     'icon': 'clear-day',
#     'ozone': 325.08,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'pressure': 1022.73,
#     'summary': 'Clear',
#     'temperature': 49.61,
#     'time': 1512327600,
#     'uvIndex': 1,
#     'visibility': 10,
#     'windBearing': 158,
#     'windGust': 4.48,
#     'windSpeed': 3.12},
#    {'apparentTemperature': 49.52,
#     'cloudCover': 0.07,
#     'dewPoint': 35.31,
#     'humidity': 0.58,
#     'icon': 'clear-day',
#     'ozone': 321.63,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'pressure': 1022.85,
#     'summary': 'Clear',
#     'temperature': 49.52,
#     'time': 1512331200,
#     'uvIndex': 1,
#     'visibility': 10,
#     'windBearing': 36,
#     'windGust': 3.17,
#     'windSpeed': 2.71},
#    {'apparentTemperature': 48.26,
#     'cloudCover': 0.02,
#     'dewPoint': 35.45,
#     'humidity': 0.61,
#     'icon': 'clear-day',
#     'ozone': 318.62,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'pressure': 1023.15,
#     'summary': 'Clear',
#     'temperature': 48.26,
#     'time': 1512334800,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 295,
#     'windGust': 2.65,
#     'windSpeed': 2.54},
#    {'apparentTemperature': 46.4,
#     'cloudCover': 0.04,
#     'dewPoint': 35.69,
#     'humidity': 0.66,
#     'icon': 'clear-night',
#     'ozone': 316.54,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1023.78,
#     'summary': 'Clear',
#     'temperature': 46.4,
#     'time': 1512338400,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 316,
#     'windGust': 2.5,
#     'windSpeed': 2.38},
#    {'apparentTemperature': 44.74,
#     'cloudCover': 0.06,
#     'dewPoint': 35.66,
#     'humidity': 0.7,
#     'icon': 'clear-night',
#     'ozone': 314.92,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1024.6,
#     'summary': 'Clear',
#     'temperature': 44.74,
#     'time': 1512342000,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 356,
#     'windGust': 3.11,
#     'windSpeed': 2.5}],
#   'icon': 'partly-cloudy-night',
#   'summary': 'Mostly cloudy throughout the day.'},
#  'latitude': 43.048122,
#  'longitude': -76.147424,
#  'minutely': {'data': [{'precipIntensity': 0,
#     'precipProbability': 0,
#     'time': 1512170520},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512170580},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512170640},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512170700},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512170760},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512170820},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512170880},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512170940},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512171000},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512171060},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512171120},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512171180},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512171240},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512171300},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512171360},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512171420},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512171480},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512171540},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512171600},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512171660},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512171720},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512171780},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512171840},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512171900},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512171960},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512172020},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512172080},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512172140},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512172200},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512172260},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512172320},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512172380},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512172440},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512172500},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512172560},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512172620},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512172680},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512172740},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512172800},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512172860},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512172920},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512172980},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512173040},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512173100},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512173160},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512173220},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512173280},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512173340},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512173400},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512173460},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512173520},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512173580},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512173640},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512173700},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512173760},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512173820},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512173880},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512173940},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512174000},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512174060},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1512174120}],
#   'icon': 'partly-cloudy-night',
#   'summary': 'Partly cloudy for the hour.'},
#  'offset': -5,
#  'timezone': 'America/New_York'}

# %%
import requests
# Now I can write the entire program...
location = input("Where are you? (eg. Syracuse, NY) : ")
geodata = google_geocode(location)
coords =geodata['results'][0]['geometry']['location']
weather = darksky_weather(coords)
current = weather['currently']
print("Current conditions in %s are %s with a temperature of %.0f degrees." % 
      (location, current['summary'], current['temperature']))
# Out:
# Where are you? (eg. Syracuse, NY) : Jackson, MS
# Current conditions in Jackson, MS are Clear with a temperature of 69 degrees.
